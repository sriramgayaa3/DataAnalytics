# %% [markdown]
# # S.GAYATHRI,2211CS010545,GROUP-3
# -------------------------------------

# %% [markdown]
# #The dataset seems to feature categorical data, potentially classifying the records into different types or categories, such as "MTW" (Monday to Wednesday) or "TL" (Travel Log), indicating specific event types or activity classifications. The numerical fields likely represent metrics or values such as distances, counts, scores, or rates, which can be analyzed to identify trends or patterns. Additionally, it might include identifier columns,
# such as unique IDs or codes, to link or distinguish different entries.
# ------------------------------------------------------------------------------------------
#
# #From this dataset, you could derive insights into temporal trends, geographic distributions, or category-specific patterns. With further analysis, you can explore statistical summaries, visualize the data through charts or maps, and conduct correlation.
# --------------------------------------------------------------------------------------------------------

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math

# %%
df = pd.read_csv("MI6_GW_MTW_TL.csv")
# Out:
# C:\Users\SRIRAMGAYATHRI22\AppData\Local\Temp\ipykernel_6440\1024735696.py:1: DtypeWarning: Columns (59) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("MI6_GW_MTW_TL.csv")

# %%
df
# Out:
#        state_name district_name block_tehsil_name village_name  \
# 0       TELENGANA    RANGAREDDY       MAHESHWARAM    GHATPALLE
# 1       TELENGANA    RANGAREDDY       MAHESHWARAM    GHATPALLE
# 2       TELENGANA    RANGAREDDY       MAHESHWARAM    GHATPALLE
# 3       TELENGANA    RANGAREDDY       MAHESHWARAM    GHATPALLE
# 4       TELENGANA    RANGAREDDY       MAHESHWARAM    GHATPALLE
# ...           ...           ...               ...          ...
# 677151  TELENGANA    RANGAREDDY       MAHESHWARAM    GHATPALLE
# 677152  TELENGANA    RANGAREDDY       MAHESHWARAM       GOLLOR
# 677153  TELENGANA    RANGAREDDY       MAHESHWARAM    GHATPALLE
# 677154  TELENGANA    RANGAREDDY       MAHESHWARAM       GOLLOR
# 677155  TELENGANA    RANGAREDDY       MAHESHWARAM       GOLLOR
#
#         s_no_of_scheme scheme_type_name     tubewell_type  \
# 0                   55        Tube well  Medium Tube well
# 1                   61        Tube well  Medium Tube well
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of        state_name district_name block_tehsil_name village_name  \
# 0       TELENGANA    RANGAREDDY       MAHESHWARAM    GHATPALLE
# 1       TELENGANA    RANGAREDDY       MAHESHWARAM    GHATPALLE
# 2       TELENGANA    RANGAREDDY       MAHESHWARAM    GHATPALLE
# 3       TELENGANA    RANGAREDDY       MAHESHWARAM    GHATPALLE
# 4       TELENGANA    RANGAREDDY       MAHESHWARAM    GHATPALLE
# ...           ...           ...               ...          ...
# 677151  TELENGANA    RANGAREDDY       MAHESHWARAM    GHATPALLE
# 677152  TELENGANA    RANGAREDDY       MAHESHWARAM       GOLLOR
# 677153  TELENGANA    RANGAREDDY       MAHESHWARAM    GHATPALLE
# 677154  TELENGANA    RANGAREDDY       MAHESHWARAM       GOLLOR
# 677155  TELENGANA    RANGAREDDY       MAHESHWARAM       GOLLOR
#
#         s_no_of_scheme scheme_type_name     tubewell_type  \
# 0                   55        Tube well  Medium Tube well
# 1                   61        Tube well  Medium Tube well
# ...

# %%
df.shape
# Out:
# (677156, 61)

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#        state_name district_name block_tehsil_name village_name  \
# 0       TELENGANA    RANGAREDDY       MAHESHWARAM    GHATPALLE
# 1       TELENGANA    RANGAREDDY       MAHESHWARAM    GHATPALLE
# 2       TELENGANA    RANGAREDDY       MAHESHWARAM    GHATPALLE
# 3       TELENGANA    RANGAREDDY       MAHESHWARAM    GHATPALLE
# 4       TELENGANA    RANGAREDDY       MAHESHWARAM    GHATPALLE
# ...           ...           ...               ...          ...
# 677151  TELENGANA    RANGAREDDY       MAHESHWARAM    GHATPALLE
# 677152  TELENGANA    RANGAREDDY       MAHESHWARAM       GOLLOR
# 677153  TELENGANA    RANGAREDDY       MAHESHWARAM    GHATPALLE
# 677154  TELENGANA    RANGAREDDY       MAHESHWARAM       GOLLOR
# 677155  TELENGANA    RANGAREDDY       MAHESHWARAM       GOLLOR
#
#         s_no_of_scheme scheme_type_name     tubewell_type  \
# 0                   55        Tube well  Medium Tube well
# 1                   61        Tube well  Medium Tube well
# ...

# %%
df = df.dropna(how="all")

# %%
df
# Out:
#        state_name district_name block_tehsil_name village_name  \
# 0       TELENGANA    RANGAREDDY       MAHESHWARAM    GHATPALLE
# 1       TELENGANA    RANGAREDDY       MAHESHWARAM    GHATPALLE
# 2       TELENGANA    RANGAREDDY       MAHESHWARAM    GHATPALLE
# 3       TELENGANA    RANGAREDDY       MAHESHWARAM    GHATPALLE
# 4       TELENGANA    RANGAREDDY       MAHESHWARAM    GHATPALLE
# ...           ...           ...               ...          ...
# 677151  TELENGANA    RANGAREDDY       MAHESHWARAM    GHATPALLE
# 677152  TELENGANA    RANGAREDDY       MAHESHWARAM       GOLLOR
# 677153  TELENGANA    RANGAREDDY       MAHESHWARAM    GHATPALLE
# 677154  TELENGANA    RANGAREDDY       MAHESHWARAM       GOLLOR
# 677155  TELENGANA    RANGAREDDY       MAHESHWARAM       GOLLOR
#
#         s_no_of_scheme scheme_type_name     tubewell_type  \
# 0                   55        Tube well  Medium Tube well
# 1                   61        Tube well  Medium Tube well
# ...

# %%
for col in df.columns:
    if df[col].dtype == 'object': 
        try:
            df[col] = pd.to_numeric(df[col])
        except ValueError:
            pass

# %%
print(df.dtypes)
# Out:
# state_name                                  object
# district_name                               object
# block_tehsil_name                           object
# village_name                                object
# s_no_of_scheme                               int64
#                                              ...
# command_area_name                           object
# ref_reason_command_area_name                object
# ref_scheme_recharge_of_ground_water_name    object
# ref_scheme_type_dugwell_name                object
# ref_scheme_type_tubewell_name               object
# Length: 61, dtype: object

# %%
print(df.isnull().sum())
# Out:
# state_name                                       0
# district_name                                    0
# block_tehsil_name                                0
# village_name                                     0
# s_no_of_scheme                                   0
#                                              ...
# command_area_name                           609649
# ref_reason_command_area_name                609648
# ref_scheme_recharge_of_ground_water_name         0
# ref_scheme_type_dugwell_name                677145
# ref_scheme_type_tubewell_name                    0
# Length: 61, dtype: int64

# %%
df.fillna({
    'scheme_owner_name': 'Unknown',  
    'tubewell_type': 'Unknown',  
    'command_area_name': 'Not Specified',  
}, inplace=True)

# %%
df.replace({'': 'Unknown'}, inplace=True)

# %%
numeric_cols = df.select_dtypes(include=['number']).columns
df[numeric_cols] = df[numeric_cols].fillna(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df[numeric_cols] = df[numeric_cols].astype(float)

# %%
df[numeric_cols] = df[numeric_cols].astype(float)

# %%
df = df.fillna(0)

# %%
df = df.infer_objects(copy=False)

# %%
print(df.isnull().sum())
# Out:
# state_name                                  0
# district_name                               0
# block_tehsil_name                           0
# village_name                                0
# s_no_of_scheme                              0
#                                            ..
# command_area_name                           0
# ref_reason_command_area_name                0
# ref_scheme_recharge_of_ground_water_name    0
# ref_scheme_type_dugwell_name                0
# ref_scheme_type_tubewell_name               0
# Length: 61, dtype: int64

# %%
plt.figure(figsize=(12, 6))
df['district_name'].value_counts().head(10).plot(kind='bar', color='skyblue')
plt.title('Top 10 Districts with Most Tube Wells')
plt.xlabel('District Name')
plt.ylabel('Number of Tube Wells')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8, 8))
df['tubewell_type'].value_counts().plot.pie(autopct='%1.1f%%', colors=['blue', 'orange', 'green'])
plt.title('Distribution of Tubewell Types')
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['total_owners_holding'])
plt.title('Distribution of Total Owners Holding')
plt.ylabel('Total Owners Holding')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['s_no_of_scheme'], df['total_owners_holding'], marker='o', linestyle='-')
plt.title('Trend of Schemes Over Serial Numbers')
plt.xlabel('Scheme Serial Number')
plt.ylabel('Total Owners Holding')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['s_no_of_scheme'], df['total_owners_holding'], marker='o', linestyle='-')
plt.title('Trend of Schemes Over Serial Numbers')
plt.xlabel('Scheme Serial Number')
plt.ylabel('Total Owners Holding')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(x=df['scheme_type_name'], y=df['total_owners_holding'])
plt.title('Violin Plot of Scheme Type vs Owners Holding')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['total_owners_holding'], df['ipu_total'], alpha=0.5, color='purple')
plt.title('Owners Holding vs IPU Total')
plt.xlabel('Total Owners Holding')
plt.ylabel('IPU Total')
plt.show();

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['total_owners_holding'], bins=30, color='green', edgecolor='black')
plt.title('Histogram of Owners Holding')
plt.xlabel('Total Owners Holding')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #CONCLUSION:
# ------------------

# %% [markdown]
#   #In conclusion, the MI6_GW_MTW_TL.csv dataset appears to contain event-based or travel-related data with both temporal and categorical dimensions, making it suitable for a variety of analyses. The presence of date, location, and metric columns suggests that the dataset could be used for time series analysis, geographic mapping, and categorical distribution exploration. The numerical fields offer the potential for statistical insights, while the categorical variables could reveal patterns or trends within specific groups or types
#   -------------------------------------------------------------
