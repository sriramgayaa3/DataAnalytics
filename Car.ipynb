# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
a = pd.read_csv(r"C:\Users\hp\Desktop\Data Analytics\car_price_dataset.csv")
a
# Out:
#            Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 0            Kia       Rio  2020          4.2    Diesel          Manual
# 1      Chevrolet    Malibu  2012          2.0    Hybrid       Automatic
# 2       Mercedes       GLA  2020          4.2    Diesel       Automatic
# 3           Audi        Q5  2023          2.0  Electric          Manual
# 4     Volkswagen      Golf  2003          2.6    Hybrid  Semi-Automatic
# ...          ...       ...   ...          ...       ...             ...
# 9995         Kia    Optima  2004          3.7    Diesel  Semi-Automatic
# 9996   Chevrolet    Impala  2002          1.4  Electric       Automatic
# 9997         BMW  3 Series  2010          3.0    Petrol       Automatic
# 9998        Ford  Explorer  2002          1.4    Hybrid       Automatic
# 9999  Volkswagen    Tiguan  2001          2.1    Diesel          Manual
#
#       Mileage  Doors  Owner_Count  Price
# 0      289944      3            5   8501
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         10000 non-null  object
#  1   Model         10000 non-null  object
#  2   Year          10000 non-null  int64
#  3   Engine_Size   10000 non-null  float64
#  4   Fuel_Type     10000 non-null  object
#  5   Transmission  10000 non-null  object
#  6   Mileage       10000 non-null  int64
#  7   Doors         10000 non-null  int64
#  8   Owner_Count   10000 non-null  int64
#  9   Price         10000 non-null  int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 781.4+ KB

# %%
a.describe()
# Out:
#                Year   Engine_Size        Mileage         Doors   Owner_Count  \
# count  10000.000000  10000.000000   10000.000000  10000.000000  10000.000000
# mean    2011.543700      3.000560  149239.111800      3.497100      2.991100
# std        6.897699      1.149324   86322.348957      1.110097      1.422682
# min     2000.000000      1.000000      25.000000      2.000000      1.000000
# 25%     2006.000000      2.000000   74649.250000      3.000000      2.000000
# 50%     2012.000000      3.000000  149587.000000      3.000000      3.000000
# 75%     2017.000000      4.000000  223577.500000      4.000000      4.000000
# max     2023.000000      5.000000  299947.000000      5.000000      5.000000
#
#              Price
# count  10000.00000
# mean    8852.96440
# std     3112.59681
# min     2000.00000
# 25%     6646.00000
# 50%     8858.50000
# 75%    11086.50000
# max    18301.00000

# %%
a.isnull().sum()
# Out:
# Brand           0
# Model           0
# Year            0
# Engine_Size     0
# Fuel_Type       0
# Transmission    0
# Mileage         0
# Doors           0
# Owner_Count     0
# Price           0
# dtype: int64

# %%
a.value_counts("Model")
# Out:
# Model
# Accord      365
# Fiesta      363
# Impala      355
# 5 Series    353
# Tiguan      352
# Focus       351
# A4          350
# Q5          350
# Elantra     347
# Golf        339
# A3          338
# Optima      336
# Civic       336
# 3 Series    335
# Explorer    334
# Malibu      333
# Passat      329
# Tucson      329
# Rio         327
# Corolla     325
# RAV4        324
# E-Class     321
# Camry       321
# Sonata      319
# Equinox     315
# GLA         315
# Sportage    313
# X5          311
# CR-V        308
# C-Class     306
# Name: count, dtype: int64

# %%
a.value_counts("Price")
# Out:
# Price
# 2000     93
# 9189      7
# 8217      7
# 9498      6
# 9754      6
#          ..
# 7741      1
# 7740      1
# 7738      1
# 7737      1
# 18301     1
# Name: count, Length: 6661, dtype: int64

# %%
a.value_counts("Year")
# Out:
# Year
# 2002    462
# 2011    449
# 2023    448
# 2012    437
# 2017    433
# 2010    431
# 2005    431
# 2007    430
# 2015    426
# 2018    425
# 2013    422
# 2019    421
# 2014    417
# 2006    415
# 2020    415
# 2001    406
# 2009    399
# 2022    397
# 2016    395
# 2004    394
# 2000    393
# 2021    391
# 2008    382
# 2003    381
# Name: count, dtype: int64

# %%
a.value_counts("Doors")
# Out:
# Doors
# 3    2575
# 4    2514
# 5    2456
# 2    2455
# Name: count, dtype: int64

# %%
a.value_counts("Engine_Size")
# Out:
# Engine_Size
# 3.7    273
# 4.4    271
# 3.6    267
# 2.5    266
# 1.5    265
# 4.0    263
# 2.8    262
# 4.6    262
# 1.3    261
# 2.2    259
# 1.4    259
# 2.6    259
# 1.6    258
# 2.0    258
# 4.1    257
# 3.5    256
# 3.3    254
# 3.1    254
# 2.9    253
# 3.8    253
# 4.7    253
# 1.2    251
# 4.5    250
# 2.7    250
# 1.8    249
# 3.2    249
# 4.9    247
# 1.7    246
# 3.4    243
# 4.3    242
# 2.4    240
# 3.0    236
# 3.9    236
# 2.1    234
# 4.2    232
# 1.9    232
# 4.8    231
# 1.1    230
# 2.3    223
# 1.0    113
# 5.0    103
# Name: count, dtype: int64

# %%
a.value_counts("Mileage")
# Out:
# Mileage
# 12478     3
# 230974    3
# 169599    2
# 184301    2
# 59372     2
#          ..
# 100576    1
# 100603    1
# 100659    1
# 100661    1
# 299947    1
# Name: count, Length: 9854, dtype: int64

# %%
a.value_counts("Owner_Count")
# Out:
# Owner_Count
# 1    2036
# 5    2036
# 2    2020
# 3    1977
# 4    1931
# Name: count, dtype: int64

# %%
X = a[['Model', 'Transmission']]
y = df['Year']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 X = a[['Model', 'Transmission']]
# ----> 2 y = df['Year']
#
# NameError: name 'df' is not defined

# %%
a

# %%
# Filter data for the year 2009
a_2009 = a[a["Year"] == 2009]

# Find the Owner_Count with the highest sales
owner_count_sales = a_2009["Owner_Count"].value_counts()

# Get the most sold Owner_Count
most_sold_owner_count = owner_count_sales.idxmax()
most_sold_count = owner_count_sales.max()

most_sold_owner_count, most_sold_count

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
sns.lineplot(x="Year", y="Price", data=a, estimator="mean", ci=None, marker="o")
plt.title("Average Car Price Over Years")
plt.xlabel("Year")
plt.ylabel("Average Price")
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7076\3421135138.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x="Year", y="Price", data=a, estimator="mean", ci=None, marker="o")

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x="Fuel_Type", y="Price", data=a, estimator="mean", palette="viridis")
plt.title("Average Price by Fuel Type")
plt.xlabel("Fuel Type")
plt.ylabel("Average Price")
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7076\3587434279.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Fuel_Type", y="Price", data=a, estimator="mean", palette="viridis")

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(x="Mileage", y="Price", data=a, alpha=0.5, color="b")
plt.title("Car Price vs Mileage")
plt.xlabel("Mileage")
plt.ylabel("Price")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x="Transmission", y="Price", data=a, palette="coolwarm")
plt.title("Car Price Distribution by Transmission Type")
plt.xlabel("Transmission Type")
plt.ylabel("Price")
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7076\3620858042.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Transmission", y="Price", data=a, palette="coolwarm")

# %%
fuel_counts = a["Fuel_Type"].value_counts()
plt.figure(figsize=(7, 7))
plt.pie(fuel_counts, labels=fuel_counts.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette("Set2"))
plt.title("Fuel Type Distribution")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.histplot(a["Price"], bins=30, kde=True, color="g")
plt.title("Distribution of Car Prices")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.histplot(a["Mileage"], bins=30, kde=True, color="purple")
plt.title("Distribution of Car Mileage")
plt.xlabel("Mileage")
plt.ylabel("Frequency")
plt.show()

# %%
numeric_a = a.select_dtypes(include=['number'])
corr_matrix = numeric_a.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Matrix")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x="Engine_Size", y="Price", data=a, palette="Set1")
plt.title("Car Price Distribution by Engine Size")
plt.xlabel("Engine Size")
plt.ylabel("Price")
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7076\2091307115.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Engine_Size", y="Price", data=a, palette="Set1")

# %%
plt.figure(figsize=(10, 5))
sns.countplot(x="Year", data=a, palette="deep")
plt.xticks(rotation=45)
plt.title("Number of Cars by Year")
plt.xlabel("Year")
plt.ylabel("Count")
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7076\2486187797.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Year", data=a, palette="deep")

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x="Engine_Size", y="Price", data=a, palette="Set1")
plt.title("Car Price Distribution by Engine Size")
plt.xlabel("Engine Size")
plt.ylabel("Price")
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7076\2588075348.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Engine_Size", y="Price", data=a, palette="Set1")
